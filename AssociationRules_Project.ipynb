# %% [markdown]
# # Apply Association rules to financial markets data

# %%
import numpy as np
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %% [markdown]
# Import market data

# %%
fx = pd.read_csv('FXdata.csv')
FwdsImplYield = pd.read_csv('FX_Fwds_ImpliedDepo_data.csv')
OIS = pd.read_csv('OIS_data.csv')
LIBOR = pd.read_csv('LIBOR_data.csv')
Equities = pd.read_csv('Equities_data.csv')
Bonds = pd.read_csv('BondYields.csv')
Oil = pd.read_csv('Oil.csv')

# %% [markdown]
# Join, clean and transform data

# %%
# Drop unused/repetitive columns
print(fx.shape)
ccySet = set(['EUR','GBP','AUD','JPY'])
for c in fx.columns:
    if c.find('1YO=')!=-1 or c.find('1YRR=')!=-1 or c.find('1YBF=')!=-1:
        fx.drop(c, axis=1, inplace=True)
    elif (c.find('1MO=')!=-1 or c.find('1MRR=')!=-1 or c.find('1MBF=')!=-1) and not c[:3] in ccySet:
        fx.drop(c, axis=1, inplace=True)
print(fx.shape)
# Out:
# (5646, 79)
# (5646, 25)

# %%
#rename columns (Reuters to market convention)
bipSet = set(['EUR=','GBP=','AUD=','NZD=','XAU='])
for c in fx.columns:
    if len(c)==4 and c[3:]=="=":
        if c in bipSet:
            fx.rename(columns={c:c[:3] + "USD"},inplace=True)
        else:
            fx.rename(columns={c:"USD" + c[:3]},inplace=True)
# drop constituents of DXY index
fx.drop('EURUSD', axis=1, inplace=True) #weight 57.6%
fx.drop('USDJPY', axis=1, inplace=True) #13.6
fx.drop('GBPUSD', axis=1, inplace=True) #11.9
fx.drop('USDCAD', axis=1, inplace=True) #9.1
fx.drop('USDSEK', axis=1, inplace=True) #4.2
fx.drop('USDCHF', axis=1, inplace=True) #3.6

fx.drop('USDDKK', axis=1, inplace=True) #pegged to EUR so essentially inverted EURUSD            
fx.columns
# Out:
# Index(['Timestamp', 'AUDUSD', 'NZDUSD', 'USDNOK', 'XAUUSD', '.DXY', 'EUR1MO=',
#        'GBP1MO=', 'JPY1MO=', 'AUD1MO=', 'EUR1MRR=', 'GBP1MRR=', 'JPY1MRR=',
#        'AUD1MRR=', 'EUR1MBF=', 'GBP1MBF=', 'JPY1MBF=', 'AUD1MBF='],
#       dtype='object')

# %%
# FwdsImplYield: convert complete term structure into level, slope and curvature
# these 3 factors explain >90% of the term structure due to high correlation across tenors
for c in FwdsImplYield.columns:
    if c.find('1M')!=-1:
        FwdsImplYield[c[:3] + '_slope'] = FwdsImplYield[c.replace('1M','1Y')]-FwdsImplYield[c]
    elif c.find('3M')!=-1:
        ccy = c[:3]
        #LIBOR-OIS
        if ccy=="USD" or ccy=="GBP" or ccy=="CHF":
            FwdsImplYield[ccy + '_LIBOR_OIS'] = LIBOR[ccy + '3MFSR='] - OIS[ccy + '3MOIS=']
        elif ccy=="EUR":
            FwdsImplYield[ccy + '_LIBOR_OIS'] = LIBOR[ccy + '3MFSR='] - OIS['EUREON3M=']
        elif ccy=="JPY":
            FwdsImplYield[ccy + '_LIBOR_OIS'] = LIBOR[ccy + '3MFSR='] - OIS[ccy + '3MOIS=FMD']
        #FXS-OIS
        if ccy=="GBP" or ccy=="CHF" or ccy=="CAD" or ccy=="AUD" or ccy=="NZD":
            FwdsImplYield[ccy + '_FXS_OIS'] = FwdsImplYield[c] - OIS[ccy + '3MOIS=']
        elif ccy=="JPY":
            FwdsImplYield[ccy + '_FXS_OIS'] = FwdsImplYield[c] - OIS[ccy + '3MOIS=FMD']
        elif ccy=="EUR":
            FwdsImplYield[ccy + '_FXS_OIS'] = FwdsImplYield[c] - OIS['EUREON3M=']
        elif ccy=="SEK":
            FwdsImplYield[ccy + '_FXS_OIS'] = FwdsImplYield[c] - OIS['SEKAMTNS3M=']
    elif c.find('6M')!=-1:
        FwdsImplYield[c[:3] + '_curve']= 1/(5+6)*(5*(FwdsImplYield[c.replace('6M','1Y')]-FwdsImplYield[c])-6*(FwdsImplYield[c]-FwdsImplYield[c.replace('6M','1M')])) # curvature
    elif c.find('1Y')!=-1:
        FwdsImplYield.rename(columns={c:c[:3] + "_1Y"},inplace=True)           #level
# drop columns
for c in FwdsImplYield.columns:
    if c.find('_')==-1 and c!='Timestamp':
        FwdsImplYield.drop(c, axis=1, inplace=True)
print(FwdsImplYield.columns)
FwdsImplYield.head()
# Out:
# Index(['Timestamp', 'EUR_1Y', 'GBP_1Y', 'JPY_1Y', 'CHF_1Y', 'CAD_1Y', 'AUD_1Y',
#        'NZD_1Y', 'SEK_1Y', 'NOK_1Y', 'DKK_1Y', 'EUR_slope', 'EUR_LIBOR_OIS',
#        'EUR_FXS_OIS', 'EUR_curve', 'GBP_slope', 'GBP_LIBOR_OIS', 'GBP_FXS_OIS',
#        'GBP_curve', 'JPY_slope', 'JPY_LIBOR_OIS', 'JPY_FXS_OIS', 'JPY_curve',
#        'CHF_slope', 'CHF_LIBOR_OIS', 'CHF_FXS_OIS', 'CHF_curve', 'CAD_slope',
#        'CAD_FXS_OIS', 'CAD_curve', 'AUD_slope', 'AUD_FXS_OIS', 'AUD_curve',
#        'NZD_slope', 'NZD_FXS_OIS', 'NZD_curve', 'SEK_slope', 'SEK_FXS_OIS',
#        'SEK_curve', 'NOK_slope', 'NOK_curve', 'DKK_slope', 'DKK_curve'],
#       dtype='object')
#     Timestamp  EUR_1Y  GBP_1Y  JPY_1Y  CHF_1Y  CAD_1Y  AUD_1Y  NZD_1Y  SEK_1Y  \
# 0  08/02/2019 -0.1725  1.1640 -0.2450 -0.5675     NaN  2.3930  2.2765  0.0940
# 1  07/02/2019 -0.1850  1.1595 -0.2375 -0.5905  2.2030  2.4275  2.2680  0.0875
# 2  06/02/2019 -0.1685  1.2015 -0.0875 -0.5670  2.2535  2.4515  2.3455  0.1005
# 3  05/02/2019 -0.1510  1.2290 -0.1630 -0.5420  2.2900  2.4865  2.4050  0.1350
# 4  04/02/2019 -0.1560  1.2395 -0.1990 -0.5475  2.2755  2.5025  2.3790  0.1205
#
#    NOK_1Y    ...      NZD_slope  NZD_FXS_OIS  NZD_curve  SEK_slope  \
# 0  1.5280    ...         0.5390       0.2875  -0.110500     0.3395
# 1  1.5240    ...         0.5240       0.2705  -0.105818     0.3460
# 2  1.5370    ...         0.5590          NaN  -0.105409     0.3560
# 3  1.5745    ...         0.6165       0.3250  -0.100773     0.3850
# 4  1.5720    ...         0.6145       0.3100  -0.124182     0.4015
#
#    SEK_FXS_OIS  SEK_curve  NOK_slope  NOK_curve  DKK_slope  DKK_curve
# 0       0.0655   0.000818     0.6175  -0.107818     0.3015  -0.021955
# 1       0.0410   0.006773     0.6120  -0.107818     0.3085  -0.042773
# 2       0.0945   0.006318     0.6545  -0.104500     0.2720  -0.020864
# 3       0.1010   0.006500     0.6970  -0.111182     0.3050  -0.085864
# 4       0.0780  -0.014000     0.7075  -0.146909     0.2825  -0.024091
#
# [5 rows x 43 columns]

# %%
for c in Bonds.columns:
    if c.find('2Y')!=-1:
        Bonds[c.replace(' 2Y','_slope')] = Bonds[c.replace(' 2Y',' 10Y')] - Bonds[c]
        Bonds.rename(columns={c:c.replace(' 2Y','_2Y')},inplace=True)
        
# drop columns
for c in Bonds.columns:
    if c.find('_')==-1 and c!='Timestamp':
        Bonds.drop(c, axis=1, inplace=True)
print(Bonds.columns)
# Out:
# Index(['Timestamp', 'US_2Y', 'Ger_2Y', 'It_2Y', 'Jp_2Y', 'GB_2Y', 'US_slope',
#        'Ger_slope', 'It_slope', 'Jp_slope', 'GB_slope'],
#       dtype='object')

# %%
data = pd.merge(fx,FwdsImplYield,how='outer',on='Timestamp',validate="one_to_one")
data = pd.merge(data,Equities,how='outer',on='Timestamp',validate="one_to_one")
data = pd.merge(data,Bonds,how='outer',on='Timestamp',validate="one_to_one")
data = pd.merge(data,Oil,how='outer',on='Timestamp',validate="one_to_one")
print(data.shape)
data.head()
# Out:
# (6311, 79)
#     Timestamp  AUDUSD  NZDUSD  USDNOK     XAUUSD    .DXY  EUR1MO=  GBP1MO=  \
# 0  08/02/2019  0.7085  0.6748  8.6071  1310.9800  96.576    6.015    9.955
# 1  07/02/2019  0.7099  0.6746  8.5946  1310.0300  96.507    5.900    9.775
# 2  06/02/2019  0.7103  0.6773  8.5408  1306.1500  96.390    5.668   10.060
# 3  05/02/2019  0.7234  0.6892  8.4831  1314.9500  96.067    5.560   10.100
# 4  04/02/2019  0.7224  0.6883  8.4584  1311.6899  95.852    5.488    9.660
#
#    JPY1MO=  AUD1MO=  ...    Ger_2Y  It_2Y  Jp_2Y  GB_2Y  US_slope  Ger_slope  \
# 0    6.050    8.550  ...    -0.575  0.594 -0.164  0.716    0.1745      0.686
# 1    6.215    8.515  ...    -0.581  0.600 -0.153  0.723    0.1750      0.739
# 2    5.992    8.387  ...    -0.556  0.477 -0.158  0.733    0.1760      0.720
# 3    5.950    8.012  ...    -0.566  0.461 -0.164  0.760    0.1820      0.732
# 4    6.105    7.807  ...    -0.572  0.439 -0.169  0.784    0.1920      0.752
#
#    It_slope  Jp_slope  GB_slope    WTI
# 0     2.347     0.136     0.464  52.45
# 1     2.348     0.145     0.455  52.60
# 2     2.360     0.144     0.482  53.88
# 3     2.334     0.151     0.471  53.69
# 4     2.314     0.156     0.494  54.83
#
# [5 rows x 79 columns]

# %%
data['Timestamp'] = pd.to_datetime(data['Timestamp'],dayfirst=True) #string to dateTime
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6311 entries, 0 to 6310
# Data columns (total 79 columns):
# Timestamp              6311 non-null datetime64[ns]
# AUDUSD                 5317 non-null float64
# NZDUSD                 5315 non-null float64
# USDNOK                 5315 non-null float64
# XAUUSD                 5305 non-null float64
# .DXY                   5259 non-null float64
# EUR1MO=                5238 non-null float64
# GBP1MO=                5300 non-null float64
# JPY1MO=                5515 non-null float64
# AUD1MO=                5310 non-null float64
# EUR1MRR=               2231 non-null float64
# GBP1MRR=               2232 non-null float64
# JPY1MRR=               2227 non-null float64
# AUD1MRR=               1602 non-null float64
# EUR1MBF=               2201 non-null float64
# GBP1MBF=               2136 non-null float64
# JPY1MBF=               2222 non-null float64
# AUD1MBF=               2191 non-null float64
# EUR_1Y                 4049 non-null float64
# GBP_1Y                 4044 non-null float64
# JPY_1Y                 5198 non-null float64
# CHF_1Y                 4138 non-null float64
# CAD_1Y                 4043 non-null float64
# AUD_1Y                 4748 non-null float64
# NZD_1Y                 4757 non-null float64
# SEK_1Y                 3739 non-null float64
# NOK_1Y                 3738 non-null float64
# DKK_1Y                 3730 non-null float64
# EUR_slope              4049 non-null float64
# EUR_LIBOR_OIS          3020 non-null float64
# EUR_FXS_OIS            3056 non-null float64
# EUR_curve              4049 non-null float64
# GBP_slope              4044 non-null float64
# GBP_LIBOR_OIS          3110 non-null float64
# GBP_FXS_OIS            3171 non-null float64
# GBP_curve              4044 non-null float64
# JPY_slope              5195 non-null float64
# JPY_LIBOR_OIS          1067 non-null float64
# JPY_FXS_OIS            1090 non-null float64
# JPY_curve              5195 non-null float64
# CHF_slope              4138 non-null float64
# CHF_LIBOR_OIS          3258 non-null float64
# CHF_FXS_OIS            3320 non-null float64
# CHF_curve              4138 non-null float64
# CAD_slope              4042 non-null float64
# CAD_FXS_OIS            3280 non-null float64
# CAD_curve              4041 non-null float64
# AUD_slope              4747 non-null float64
# AUD_FXS_OIS            3100 non-null float64
# AUD_curve              4746 non-null float64
# NZD_slope              4755 non-null float64
# NZD_FXS_OIS            3284 non-null float64
# NZD_curve              4754 non-null float64
# SEK_slope              3738 non-null float64
# SEK_FXS_OIS            3593 non-null float64
# SEK_curve              3738 non-null float64
# NOK_slope              3738 non-null float64
# NOK_curve              3738 non-null float64
# DKK_slope              3729 non-null float64
# DKK_curve              3729 non-null float64
# S&P 500 (USD)          5127 non-null float64
# EURO STOXX 50 (EUR)    5217 non-null float64
# NIKKEI                 5001 non-null float64
# MSCI EM                5309 non-null float64
# Baltic Dry Index       5095 non-null float64
# VIX                    5128 non-null float64
# EURO STOXX 50 VOL      5119 non-null float64
# NIKKEI VOL             5001 non-null float64
# US_2Y                  5142 non-null float64
# Ger_2Y                 4884 non-null float64
# It_2Y                  6065 non-null float64
# Jp_2Y                  4978 non-null float64
# GB_2Y                  5346 non-null float64
# US_slope               5115 non-null float64
# Ger_slope              4878 non-null float64
# It_slope               5132 non-null float64
# Jp_slope               4978 non-null float64
# GB_slope               5182 non-null float64
# WTI                    4301 non-null float64
# dtypes: datetime64[ns](1), float64(78)
# memory usage: 3.9 MB

# %%
data.head()
# Out:
#    Timestamp  AUDUSD  NZDUSD  USDNOK     XAUUSD    .DXY  EUR1MO=  GBP1MO=  \
# 0 2019-02-08  0.7085  0.6748  8.6071  1310.9800  96.576    6.015    9.955
# 1 2019-02-07  0.7099  0.6746  8.5946  1310.0300  96.507    5.900    9.775
# 2 2019-02-06  0.7103  0.6773  8.5408  1306.1500  96.390    5.668   10.060
# 3 2019-02-05  0.7234  0.6892  8.4831  1314.9500  96.067    5.560   10.100
# 4 2019-02-04  0.7224  0.6883  8.4584  1311.6899  95.852    5.488    9.660
#
#    JPY1MO=  AUD1MO=  ...    Ger_2Y  It_2Y  Jp_2Y  GB_2Y  US_slope  Ger_slope  \
# 0    6.050    8.550  ...    -0.575  0.594 -0.164  0.716    0.1745      0.686
# 1    6.215    8.515  ...    -0.581  0.600 -0.153  0.723    0.1750      0.739
# 2    5.992    8.387  ...    -0.556  0.477 -0.158  0.733    0.1760      0.720
# 3    5.950    8.012  ...    -0.566  0.461 -0.164  0.760    0.1820      0.732
# 4    6.105    7.807  ...    -0.572  0.439 -0.169  0.784    0.1920      0.752
#
#    It_slope  Jp_slope  GB_slope    WTI
# 0     2.347     0.136     0.464  52.45
# 1     2.348     0.145     0.455  52.60
# 2     2.360     0.144     0.482  53.88
# 3     2.334     0.151     0.471  53.69
# 4     2.314     0.156     0.494  54.83
#
# [5 rows x 79 columns]

# %% [markdown]
# Close to close change: up, unchanged or down

# %%
# create new df with XXX_Up and XXX_Down; boolean values
data.fillna(method='backfill')
DailyChg = data - data.shift(periods=1, axis='rows')
DailyChg=DailyChg.drop('Timestamp', axis=1)
DailyChg.drop(DailyChg.index[0], inplace=True)
#DailyChg=DailyChg.dropna(axis=0)
print(DailyChg.shape)
#DailyChg.head()
# Out:
# (6310, 78)

# %%
for c in DailyChg.columns:
    DailyChg[c + '_Up'] = DailyChg[c] > 0
    DailyChg[c + '_Down'] = DailyChg[c] < 0
    DailyChg.drop(c, axis=1, inplace=True)
DailyChg.head()
# Out:
#    AUDUSD_Up  AUDUSD_Down  NZDUSD_Up  NZDUSD_Down  USDNOK_Up  USDNOK_Down  \
# 1       True        False      False         True      False         True
# 2       True        False       True        False      False         True
# 3       True        False       True        False      False         True
# 4      False         True      False         True      False         True
# 5       True        False       True        False      False         True
#
#    XAUUSD_Up  XAUUSD_Down  .DXY_Up  .DXY_Down    ...     Ger_slope_Up  \
# 1      False         True    False       True    ...             True
# 2      False         True    False       True    ...            False
# 3       True        False    False       True    ...             True
# 4      False         True    False       True    ...             True
# 5       True        False    False       True    ...            False
#
#    Ger_slope_Down  It_slope_Up  It_slope_Down  Jp_slope_Up  Jp_slope_Down  \
# 1           False         True          False         True          False
# 2            True         True          False        False           True
# 3           False        False           True         True          False
# 4           False        False           True         True          False
# 5            True        False           True        False           True
#
#    GB_slope_Up  GB_slope_Down  WTI_Up  WTI_Down
# 1        False           True    True     False
# 2         True          False    True     False
# 3        False           True   False      True
# 4         True          False    True     False
# 5        False           True    True     False
#
# [5 rows x 156 columns]

# %% [markdown]
# # Most common sets market conditions

# %% [markdown]
# Determining the most frequent combination of market close to close moves (itemset)
# Support(itemset) = percentage of trading days for which set of 'close to close' changes in market prices (binary up or down) occurred.
# Using lambda function to only show combinations of market changes (itemsets of length >=2)

# %%
frequent_itemsets = apriori(DailyChg, min_support=0.15, use_colnames=True)
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets = frequent_itemsets[ (frequent_itemsets['length'] == 2)]
frequent_itemsets.sort_values(by=['support','length'],ascending=False,inplace=True)
frequent_itemsets
# Out:
#        support                                          itemsets  length
# 202   0.336767                        (AUDUSD_Down, NZDUSD_Down)       2
# 2304  0.336450                      (VIX_Up, S&P 500 (USD)_Down)       2
# 2358  0.326624  (EURO STOXX 50 VOL_Up, EURO STOXX 50 (EUR)_Down)       2
# 408   0.305071                              (.DXY_Up, USDNOK_Up)       2
# 138   0.302377                            (AUDUSD_Up, NZDUSD_Up)       2
# 480   0.299525                          (USDNOK_Down, .DXY_Down)       2
# 1278  0.293502                         (JPY_slope_Up, JPY_1Y_Up)       2
# 1331  0.291918                     (JPY_slope_Down, JPY_1Y_Down)       2
# 203   0.290808                          (USDNOK_Up, AUDUSD_Down)       2
# 800   0.287163                          (EUR1MO=_Up, GBP1MO=_Up)       2
# 1535  0.286529                         (NZD_1Y_Up, NZD_slope_Up)       2
# 2456  0.284786              (EURO STOXX 50 VOL_Up, MSCI EM_Down)       2
# 2354  0.284152          (MSCI EM_Down, EURO STOXX 50 (EUR)_Down)       2
# 1449  0.283835                         (AUD_slope_Up, AUD_1Y_Up)       2
# 2527  0.283835                    (EURO STOXX 50 VOL_Up, VIX_Up)       2
# 2333  0.282567  (EURO STOXX 50 VOL_Down, EURO STOXX 50 (EUR)_Up)       2
# 205   0.278764                            (.DXY_Up, AUDUSD_Down)       2
# 338   0.278764                          (USDNOK_Up, NZDUSD_Down)       2
# 802   0.275594                          (AUD1MO=_Up, EUR1MO=_Up)       2
# 204   0.275277                        (AUDUSD_Down, XAUUSD_Down)       2
# 801   0.275119                          (EUR1MO=_Up, JPY1MO=_Up)       2
# 995   0.275119                          (AUD1MO=_Up, JPY1MO=_Up)       2
# 246   0.272266                       (AUDUSD_Down, MSCI EM_Down)       2
# 1490  0.271949                     (AUD_slope_Down, AUD_1Y_Down)       2
# 2280  0.271474                      (VIX_Down, S&P 500 (USD)_Up)       2
# 340   0.271157                            (.DXY_Up, NZDUSD_Down)       2
# 2305  0.270998        (EURO STOXX 50 VOL_Up, S&P 500 (USD)_Down)       2
# 2298  0.266878    (S&P 500 (USD)_Down, EURO STOXX 50 (EUR)_Down)       2
# 2301  0.266719                (MSCI EM_Down, S&P 500 (USD)_Down)       2
# 339   0.266561                        (NZDUSD_Down, XAUUSD_Down)       2
# ...        ...                                               ...     ...
# 2337  0.150396              (US_2Y_Down, EURO STOXX 50 (EUR)_Up)       2
# 2431  0.150396                              (VIX_Up, MSCI EM_Up)       2
# 348   0.150238                       (AUD1MO=_Down, NZDUSD_Down)       2
# 421   0.150238                          (USDNOK_Up, CAD_1Y_Down)       2
# 1161  0.150238                         (AUD1MO=_Down, NZD_1Y_Up)       2
# 1250  0.150238                       (GBP_1Y_Up, CAD_curve_Down)       2
# 1266  0.150238                     (GBP_1Y_Down, CAD_curve_Down)       2
# 1383  0.150238                         (CHF_1Y_Up, EUR_slope_Up)       2
# 1489  0.150238                     (AUD_1Y_Down, CAD_curve_Down)       2
# 1511  0.150238                        (AUD_1Y_Down, US_slope_Up)       2
# 1684  0.150238                    (JPY_curve_Up, EUR_curve_Down)       2
# 1848  0.150238                      (JPY_curve_Up, CHF_slope_Up)       2
# 1918  0.150238                 (NIKKEI VOL_Down, JPY_curve_Down)       2
# 2004  0.150238              (CAD_curve_Up, EURO STOXX 50 VOL_Up)       2
# 2744  0.150238                     (Ger_slope_Down, Jp_slope_Up)       2
# 616   0.150079                        (XAUUSD_Down, CHF_1Y_Down)       2
# 683   0.150079                            (.DXY_Up, CHF_1Y_Down)       2
# 781   0.150079                             (US_2Y_Up, .DXY_Down)       2
# 960   0.150079                         (GBP1MO=_Down, AUD_1Y_Up)       2
# 999   0.150079                           (JPY1MO=_Up, CHF_1Y_Up)       2
# 1006  0.150079                      (JPY1MO=_Up, EUR_slope_Down)       2
# 1008  0.150079                        (GBP_slope_Up, JPY1MO=_Up)       2
# 1167  0.150079                    (AUD1MO=_Down, AUD_curve_Down)       2
# 1328  0.150079                       (EUR_curve_Up, JPY_1Y_Down)       2
# 1330  0.150079                       (JPY_1Y_Down, GBP_curve_Up)       2
# 1428  0.150079                     (GBP_curve_Down, CAD_1Y_Down)       2
# 1437  0.150079                       (MSCI EM_Down, CAD_1Y_Down)       2
# 1466  0.150079               (EURO STOXX 50 VOL_Down, AUD_1Y_Up)       2
# 1734  0.150079                    (CAD_slope_Down, GBP_curve_Up)       2
# 2664  0.150079                             (WTI_Down, Ger_2Y_Up)       2
#
# [2626 rows x 3 columns]

# %% [markdown]
# # Creating Rules: First set of Association Rules

# %% [markdown]
# Support = How often is a condition true as a share of all observations (trading days).
#
# Confidence(A → C) = How often is a rule true. This corresponds to conditional probability that C(onsequent) has moved as described by the rule given A(ntecedent) has moved as described.
#
# Lift = confidence(A → C)/support(C). How much more likely is C to have moved consistent with the rule on a day where A behaved as described.
#
# Leverage = support(A → C)−support(A) * support(C). Range [-1,1]. Difference between observed frequency to base case of A,B being independent.

# %%
frequent_itemsets = apriori(DailyChg, min_support=0.1, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.5)
rules["antecedent_len"] = rules["antecedents"].apply(lambda x: len(x))
rules.sort_values(by=['confidence','lift'],ascending=False,inplace=True)
rules[ (rules['antecedent_len'] >= 2)]
# Out:
#                                              antecedents  \
# 44674  (GBP_slope_Up, EUR_slope_Up, GBP_curve_Up, EUR...
# 37554            (GBP_slope_Up, GBP_curve_Up, EUR_1Y_Up)
# 44800  (GBP_slope_Down, EUR_1Y_Down, GBP_curve_Down, ...
# 44758  (GBP_slope_Down, EUR_1Y_Down, NZD_1Y_Down, EUR...
# 38183            (GBP_1Y_Up, EUR_curve_Up, EUR_slope_Up)
# 44653  (GBP_1Y_Up, EUR_slope_Up, EUR_curve_Up, EUR_1Y...
# 37830         (GBP_slope_Down, EUR_1Y_Down, NZD_1Y_Down)
# 37913      (GBP_curve_Down, EUR_1Y_Down, GBP_slope_Down)
# 44822  (GBP_1Y_Down, EUR_1Y_Down, NZD_slope_Down, EUR...
# 38386      (NOK_slope_Down, GBP_1Y_Down, EUR_slope_Down)
# 44652  (GBP_slope_Up, EUR_slope_Up, EUR_curve_Up, EUR...
# 44779  (EUR_1Y_Down, GBP_slope_Down, EUR_curve_Down, ...
# 38379      (GBP_1Y_Down, NZD_slope_Down, EUR_slope_Down)
# 44718  (GBP_slope_Up, GBP_1Y_Up, NZD_slope_Up, EUR_1Y...
# 44781  (GBP_1Y_Down, GBP_slope_Down, EUR_curve_Down, ...
# 37847      (GBP_1Y_Down, EUR_curve_Down, EUR_slope_Down)
# 45856  (GBP_slope_Up, GBP_1Y_Up, NZD_slope_Up, EUR_1Y...
# 37892      (EUR_curve_Down, GBP_slope_Down, EUR_1Y_Down)
# 45904  (NOK_1Y_Up, SEK_1Y_Up, CHF_slope_Up, SEK_slope...
# 45959  (CHF_slope_Down, CHF_1Y_Down, SEK_1Y_Down, NOK...
# 45955  (SEK_slope_Down, CHF_slope_Down, CHF_1Y_Down, ...
# 37536            (GBP_slope_Up, EUR_curve_Up, EUR_1Y_Up)
# 37805         (GBP_slope_Down, EUR_1Y_Down, CAD_1Y_Down)
# 37770            (GBP_slope_Up, NZD_slope_Up, EUR_1Y_Up)
# 37470            (GBP_1Y_Up, EUR_curve_Up, EUR_slope_Up)
# 38066             (GBP_1Y_Up, JPY_1Y_Down, EUR_slope_Up)
# 44651  (GBP_slope_Up, GBP_1Y_Up, EUR_slope_Up, EUR_cu...
# 45128  (SEK_1Y_Down, CHF_slope_Down, NOK_1Y_Down, SEK...
# 44760  (GBP_1Y_Down, EUR_1Y_Down, NZD_1Y_Down, EUR_sl...
# 45079  (CHF_slope_Down, NOK_1Y_Down, SEK_slope_Down, ...
# ...                                                  ...
# 26548                               (US_2Y_Up, It_2Y_Up)
# 8434               (USDNOK_Up, EURO STOXX 50 (EUR)_Down)
# 25467                (EURO STOXX 50 (EUR)_Up, NIKKEI_Up)
# 26996                           (GB_2Y_Down, US_2Y_Down)
# 35049               (EUR1MO=_Up, JPY1MO=_Up, GBP1MO=_Up)
# 27694                               (US_2Y_Up, GB_2Y_Up)
# 9998                              (.DXY_Up, XAUUSD_Down)
# 5027                   (AUDUSD_Down, S&P 500 (USD)_Down)
# 32017          (AUDUSD_Down, VIX_Up, S&P 500 (USD)_Down)
# 33509          (NZDUSD_Down, VIX_Up, S&P 500 (USD)_Down)
# 3592                            (GB_2Y_Up, Ger_slope_Up)
# 11498                                (.DXY_Down, VIX_Up)
# 35751  (EUR1MO=_Up, EURO STOXX 50 VOL_Up, EURO STOXX ...
# 10040                             (.DXY_Up, XAUUSD_Down)
# 3536                             (AUDUSD_Up, MSCI EM_Up)
# 9644                    (JPY1MO=_Up, S&P 500 (USD)_Down)
# 9841                        (NIKKEI VOL_Down, NIKKEI_Up)
# 34637  (VIX_Up, EURO STOXX 50 (EUR)_Down, S&P 500 (US...
# 23560                (EURO STOXX 50 VOL_Up, NIKKEI_Down)
# 29582            (AUDUSD_Down, NZDUSD_Down, XAUUSD_Down)
# 11637            (NIKKEI_Down, EURO STOXX 50 (EUR)_Down)
# 9402                            (GB_slope_Up, Ger_2Y_Up)
# 22202                       (GBP_slope_Up, EUR_slope_Up)
# 5628                              (NZDUSD_Up, XAUUSD_Up)
# 21965                          (DKK_1Y_Up, DKK_slope_Up)
# 12926                              (US_2Y_Up, Ger_2Y_Up)
# 16040                              (US_2Y_Up, Ger_2Y_Up)
# 10487                   (NOK_slope_Down, SEK_slope_Down)
# 7456                                (GB_2Y_Up, It_2Y_Up)
# 5625                              (NZDUSD_Up, XAUUSD_Up)
#
#                       consequents  antecedent support  consequent support  \
# 44674                 (GBP_1Y_Up)            0.106339            0.297623
# 37554                 (GBP_1Y_Up)            0.113788            0.297623
# 44800               (GBP_1Y_Down)            0.103645            0.287956
# 44758               (GBP_1Y_Down)            0.106815            0.287956
# 38183              (GBP_slope_Up)            0.113312            0.302536
# 44653              (GBP_slope_Up)            0.107765            0.302536
# 37830               (GBP_1Y_Down)            0.114897            0.287956
# 37913               (GBP_1Y_Down)            0.110618            0.287956
# 44822            (GBP_slope_Down)            0.106022            0.292868
# 38386            (GBP_slope_Down)            0.104596            0.292868
# 44652                 (GBP_1Y_Up)            0.107924            0.297623
# 44779               (GBP_1Y_Down)            0.106815            0.287956
# 38379            (GBP_slope_Down)            0.116165            0.292868
# 44718              (EUR_slope_Up)            0.121395            0.303645
# 44781               (EUR_1Y_Down)            0.107290            0.289540
# 37847               (EUR_1Y_Down)            0.113154            0.289540
# 45856              (EUR_slope_Up)            0.105864            0.303645
# 37892               (GBP_1Y_Down)            0.115689            0.287956
# 45904              (NOK_slope_Up)            0.105071            0.269731
# 45959            (SEK_slope_Down)            0.111094            0.270681
# 45955            (NOK_slope_Down)            0.111094            0.276704
# 37536                 (GBP_1Y_Up)            0.117591            0.297623
# 37805               (GBP_1Y_Down)            0.110460            0.287956
# 37770              (EUR_slope_Up)            0.131062            0.303645
# 37470                 (EUR_1Y_Up)            0.113312            0.300317
# 38066              (GBP_slope_Up)            0.106656            0.302536
# 44651                 (EUR_1Y_Up)            0.108875            0.300317
# 45128            (NOK_slope_Down)            0.121078            0.276704
# 44760            (GBP_slope_Down)            0.108082            0.292868
# 45079            (NOK_slope_Down)            0.119017            0.276704
# ...                           ...                 ...                 ...
# 26548                (MSCI EM_Up)            0.209826            0.364659
# 8434                 (US_2Y_Down)            0.213946            0.372108
# 25467     (Baltic Dry Index_Down)            0.202219            0.378605
# 26996     (Baltic Dry Index_Down)            0.202219            0.378605
# 35049     (Baltic Dry Index_Down)            0.203803            0.378605
# 27694               (It_slope_Up)            0.200317            0.379239
# 9998                (JPY_1Y_Down)            0.262758            0.379398
# 5027              (GB_slope_Down)            0.243740            0.379556
# 32017             (GB_slope_Down)            0.207924            0.379556
# 33509             (GB_slope_Down)            0.200634            0.379556
# 3592                  (AUDUSD_Up)            0.210460            0.379873
# 11498                 (JPY_1Y_Up)            0.209509            0.380507
# 35751                 (JPY_1Y_Up)            0.200000            0.380507
# 10040    (EURO STOXX 50 (EUR)_Up)            0.262758            0.383201
# 3536              (It_slope_Down)            0.213312            0.384786
# 9644                  (XAUUSD_Up)            0.234548            0.385420
# 9841                  (XAUUSD_Up)            0.215214            0.385420
# 34637                 (XAUUSD_Up)            0.227258            0.385420
# 23560              (JPY_curve_Up)            0.223772            0.388273
# 29582               (GB_slope_Up)            0.231696            0.389540
# 11637                 (.DXY_Down)            0.218067            0.389699
# 9402                (USDNOK_Down)            0.223772            0.396513
# 22202  (EURO STOXX 50 (EUR)_Down)            0.232647            0.400158
# 5628              (NIKKEI VOL_Up)            0.238986            0.400475
# 21965        (S&P 500 (USD)_Down)            0.216165            0.402853
# 12926                (EUR1MO=_Up)            0.201268            0.406498
# 16040                (AUD1MO=_Up)            0.201268            0.410618
# 10487               (XAUUSD_Down)            0.200951            0.411727
# 7456                (NZDUSD_Down)            0.220602            0.412837
# 5625       (EURO STOXX 50 VOL_Up)            0.238986            0.418859
#
#         support  confidence      lift  leverage  conviction  antecedent_len
# 44674  0.103011    0.968703  3.254802  0.071362   22.442623               4
# 37554  0.109984    0.966574  3.247647  0.076118   21.012784               3
# 44800  0.100000    0.964832  3.350627  0.070155   20.246827               4
# 44758  0.102694    0.961424  3.338793  0.071936   18.458381               4
# 38183  0.108875    0.960839  3.175953  0.074594   17.810250               3
# 44653  0.103487    0.960294  3.174152  0.070884   17.565769               4
# 37830  0.110301    0.960000  3.333847  0.077216   17.801109               3
# 37913  0.106181    0.959885  3.333449  0.074328   17.750249               3
# 44822  0.101743    0.959641  3.276697  0.070693   17.521148               4
# 38386  0.100317    0.959091  3.274818  0.069684   17.285438               3
# 44652  0.103487    0.958884  3.221809  0.071366   17.082816               4
# 44779  0.102377    0.958457  3.328488  0.071619   17.139925               4
# 38379  0.111252    0.957708  3.270096  0.077231   16.720239               3
# 44718  0.116006    0.955614  3.147141  0.079145   15.688468               4
# 44781  0.102377    0.954210  3.295601  0.071312   15.515521               4
# 37847  0.107924    0.953782  3.294122  0.075161   15.371762               3
# 45856  0.100951    0.953593  3.140486  0.068806   15.005327               5
# 37892  0.110301    0.953425  3.311012  0.076988   15.288012               3
# 45904  0.100158    0.953243  3.534055  0.071818   15.618343               5
# 45959  0.105864    0.952924  3.520464  0.075793   15.492494               5
# 45955  0.105864    0.952924  3.443845  0.075124   15.364568               5
# 37536  0.112044    0.952830  3.201469  0.077047   14.890396               3
# 37805  0.105230    0.952654  3.308337  0.073422   15.039240               3
# 37770  0.124723    0.951632  3.134029  0.084926   14.397139               3
# 37470  0.107765    0.951049  3.166817  0.073736   14.293525               3
# 38066  0.101426    0.950966  3.143318  0.069159   14.224046               3
# 44651  0.103487    0.950509  3.165021  0.070790   14.137713               4
# 45128  0.115055    0.950262  3.434222  0.081553   14.542064               4
# 44760  0.102694    0.950147  3.244278  0.071040   14.184227               4
# 45079  0.112995    0.949401  3.431111  0.080063   14.294620               4
# ...         ...         ...       ...       ...         ...             ...
# 26548  0.104913    0.500000  1.371143  0.028398    1.270681               2
# 8434   0.106973    0.500000  1.343697  0.027362    1.255784               2
# 25467  0.101109    0.500000  1.320636  0.024548    1.242789               2
# 26996  0.101109    0.500000  1.320636  0.024548    1.242789               2
# 35049  0.101902    0.500000  1.320636  0.024741    1.242789               3
# 27694  0.100158    0.500000  1.318429  0.024190    1.241521               2
# 9998   0.131379    0.500000  1.317878  0.031689    1.241204               2
# 5027   0.121870    0.500000  1.317328  0.029357    1.240887               2
# 32017  0.103962    0.500000  1.317328  0.025043    1.240887               3
# 33509  0.100317    0.500000  1.317328  0.024165    1.240887               3
# 3592   0.105230    0.500000  1.316229  0.025282    1.240254               2
# 11498  0.104754    0.500000  1.314036  0.025035    1.238986               2
# 35751  0.100000    0.500000  1.314036  0.023899    1.238986               3
# 10040  0.131379    0.500000  1.304797  0.030690    1.233597               2
# 3536   0.106656    0.500000  1.299423  0.024577    1.230428               2
# 9644   0.117274    0.500000  1.297286  0.026875    1.229160               2
# 9841   0.107607    0.500000  1.297286  0.024659    1.229160               2
# 34637  0.113629    0.500000  1.297286  0.026039    1.229160               3
# 23560  0.111886    0.500000  1.287755  0.025001    1.223455               2
# 29582  0.115848    0.500000  1.283564  0.025593    1.220919               3
# 11637  0.109033    0.500000  1.283042  0.024053    1.220602               2
# 9402   0.111886    0.500000  1.260991  0.023157    1.206973               2
# 22202  0.116323    0.500000  1.249505  0.023228    1.199683               2
# 5628   0.119493    0.500000  1.248516  0.023785    1.199049               2
# 21965  0.108082    0.500000  1.241149  0.021000    1.194295               2
# 12926  0.100634    0.500000  1.230019  0.018819    1.187005               2
# 16040  0.100634    0.500000  1.217677  0.017990    1.178764               2
# 10487  0.100475    0.500000  1.214396  0.017738    1.176545               2
# 7456   0.110301    0.500000  1.211132  0.019228    1.174326               2
# 5625   0.119493    0.500000  1.193719  0.019392    1.162282               2
#
# [43130 rows x 10 columns]

# %%
#Interesting rule example: risk off
#SP500 down and JPY 1m ATM vol up -->XAUUSD up
print('antecedents: ' + str(rules.loc[9644].antecedents))
print('consequents: ' + str(rules.loc[9644].consequents))
print('lift: ' + "{0:.2f}".format(round(rules.loc[9644].lift,2)) + ' confidence: ' + "{0:.2f}".format(round(rules.loc[9644].confidence,2)))
# Out:
# antecedents: frozenset({'JPY1MO=_Up', 'S&P 500 (USD)_Down'})
# consequents: frozenset({'XAUUSD_Up'})
# lift: 1.30 confidence: 0.50

# %% [markdown]
# ### Rules with significant lift

# %%
rules[ (rules['antecedent_len'] >= 3) & (rules['lift'] > 3) ]
# Out:
#                                              antecedents  \
# 44674  (GBP_slope_Up, EUR_slope_Up, GBP_curve_Up, EUR...
# 37554            (GBP_slope_Up, GBP_curve_Up, EUR_1Y_Up)
# 44800  (GBP_slope_Down, EUR_1Y_Down, GBP_curve_Down, ...
# 44758  (GBP_slope_Down, EUR_1Y_Down, NZD_1Y_Down, EUR...
# 38183            (GBP_1Y_Up, EUR_curve_Up, EUR_slope_Up)
# 44653  (GBP_1Y_Up, EUR_slope_Up, EUR_curve_Up, EUR_1Y...
# 37830         (GBP_slope_Down, EUR_1Y_Down, NZD_1Y_Down)
# 37913      (GBP_curve_Down, EUR_1Y_Down, GBP_slope_Down)
# 44822  (GBP_1Y_Down, EUR_1Y_Down, NZD_slope_Down, EUR...
# 38386      (NOK_slope_Down, GBP_1Y_Down, EUR_slope_Down)
# 44652  (GBP_slope_Up, EUR_slope_Up, EUR_curve_Up, EUR...
# 44779  (EUR_1Y_Down, GBP_slope_Down, EUR_curve_Down, ...
# 38379      (GBP_1Y_Down, NZD_slope_Down, EUR_slope_Down)
# 44718  (GBP_slope_Up, GBP_1Y_Up, NZD_slope_Up, EUR_1Y...
# 44781  (GBP_1Y_Down, GBP_slope_Down, EUR_curve_Down, ...
# 37847      (GBP_1Y_Down, EUR_curve_Down, EUR_slope_Down)
# 45856  (GBP_slope_Up, GBP_1Y_Up, NZD_slope_Up, EUR_1Y...
# 37892      (EUR_curve_Down, GBP_slope_Down, EUR_1Y_Down)
# 45904  (NOK_1Y_Up, SEK_1Y_Up, CHF_slope_Up, SEK_slope...
# 45959  (CHF_slope_Down, CHF_1Y_Down, SEK_1Y_Down, NOK...
# 45955  (SEK_slope_Down, CHF_slope_Down, CHF_1Y_Down, ...
# 37536            (GBP_slope_Up, EUR_curve_Up, EUR_1Y_Up)
# 37805         (GBP_slope_Down, EUR_1Y_Down, CAD_1Y_Down)
# 37770            (GBP_slope_Up, NZD_slope_Up, EUR_1Y_Up)
# 37470            (GBP_1Y_Up, EUR_curve_Up, EUR_slope_Up)
# 38066             (GBP_1Y_Up, JPY_1Y_Down, EUR_slope_Up)
# 44651  (GBP_slope_Up, GBP_1Y_Up, EUR_slope_Up, EUR_cu...
# 45128  (SEK_1Y_Down, CHF_slope_Down, NOK_1Y_Down, SEK...
# 44760  (GBP_1Y_Down, EUR_1Y_Down, NZD_1Y_Down, EUR_sl...
# 45079  (CHF_slope_Down, NOK_1Y_Down, SEK_slope_Down, ...
# ...                                                  ...
# 44683               (GBP_slope_Up, GBP_1Y_Up, EUR_1Y_Up)
# 44680               (GBP_1Y_Up, EUR_slope_Up, EUR_1Y_Up)
# 44660            (GBP_slope_Up, EUR_slope_Up, EUR_1Y_Up)
# 44809      (GBP_slope_Down, GBP_1Y_Down, EUR_slope_Down)
# 44707               (GBP_slope_Up, GBP_1Y_Up, EUR_1Y_Up)
# 44678            (GBP_slope_Up, EUR_slope_Up, EUR_1Y_Up)
# 44706               (GBP_1Y_Up, EUR_slope_Up, EUR_1Y_Up)
# 45883               (GBP_slope_Up, GBP_1Y_Up, EUR_1Y_Up)
# 45877               (GBP_1Y_Up, EUR_slope_Up, EUR_1Y_Up)
# 45594              (USDNOK_Up, NZDUSD_Down, XAUUSD_Down)
# 44677            (GBP_slope_Up, GBP_1Y_Up, EUR_slope_Up)
# 44705            (GBP_slope_Up, EUR_slope_Up, EUR_1Y_Up)
# 45848   (MSCI EM_Down, VIX_Up, EURO STOXX 50 (EUR)_Down)
# 45874            (GBP_slope_Up, EUR_slope_Up, EUR_1Y_Up)
# 45772   (MSCI EM_Down, VIX_Up, EURO STOXX 50 (EUR)_Down)
# 44704            (GBP_slope_Up, GBP_1Y_Up, EUR_slope_Up)
# 45738   (MSCI EM_Down, VIX_Up, EURO STOXX 50 (EUR)_Down)
# 45872            (GBP_slope_Up, GBP_1Y_Up, EUR_slope_Up)
# 45813   (MSCI EM_Down, VIX_Up, EURO STOXX 50 (EUR)_Down)
# 45592              (USDNOK_Up, AUDUSD_Down, XAUUSD_Down)
# 45849  (EURO STOXX 50 VOL_Up, MSCI EM_Down, S&P 500 (...
# 45779  (EURO STOXX 50 VOL_Up, MSCI EM_Down, S&P 500 (...
# 45637                 (AUDUSD_Down, NZDUSD_Down, VIX_Up)
# 45850       (EURO STOXX 50 VOL_Up, MSCI EM_Down, VIX_Up)
# 45780       (EURO STOXX 50 VOL_Up, MSCI EM_Down, VIX_Up)
# 45741  (EURO STOXX 50 VOL_Up, MSCI EM_Down, S&P 500 (...
# 45635     (AUDUSD_Down, NZDUSD_Down, S&P 500 (USD)_Down)
# 45814  (EURO STOXX 50 VOL_Up, MSCI EM_Down, S&P 500 (...
# 45745       (EURO STOXX 50 VOL_Up, MSCI EM_Down, VIX_Up)
# 45815       (EURO STOXX 50 VOL_Up, MSCI EM_Down, VIX_Up)
#
#                                              consequents  antecedent support  \
# 44674                                        (GBP_1Y_Up)            0.106339
# 37554                                        (GBP_1Y_Up)            0.113788
# 44800                                      (GBP_1Y_Down)            0.103645
# 44758                                      (GBP_1Y_Down)            0.106815
# 38183                                     (GBP_slope_Up)            0.113312
# 44653                                     (GBP_slope_Up)            0.107765
# 37830                                      (GBP_1Y_Down)            0.114897
# 37913                                      (GBP_1Y_Down)            0.110618
# 44822                                   (GBP_slope_Down)            0.106022
# 38386                                   (GBP_slope_Down)            0.104596
# 44652                                        (GBP_1Y_Up)            0.107924
# 44779                                      (GBP_1Y_Down)            0.106815
# 38379                                   (GBP_slope_Down)            0.116165
# 44718                                     (EUR_slope_Up)            0.121395
# 44781                                      (EUR_1Y_Down)            0.107290
# 37847                                      (EUR_1Y_Down)            0.113154
# 45856                                     (EUR_slope_Up)            0.105864
# 37892                                      (GBP_1Y_Down)            0.115689
# 45904                                     (NOK_slope_Up)            0.105071
# 45959                                   (SEK_slope_Down)            0.111094
# 45955                                   (NOK_slope_Down)            0.111094
# 37536                                        (GBP_1Y_Up)            0.117591
# 37805                                      (GBP_1Y_Down)            0.110460
# 37770                                     (EUR_slope_Up)            0.131062
# 37470                                        (EUR_1Y_Up)            0.113312
# 38066                                     (GBP_slope_Up)            0.106656
# 44651                                        (EUR_1Y_Up)            0.108875
# 45128                                   (NOK_slope_Down)            0.121078
# 44760                                   (GBP_slope_Down)            0.108082
# 45079                                   (NOK_slope_Down)            0.119017
# ...                                                  ...                 ...
# 44683                       (EUR_slope_Up, GBP_curve_Up)            0.183518
# 44680                       (GBP_slope_Up, GBP_curve_Up)            0.184152
# 44660                          (GBP_1Y_Up, EUR_curve_Up)            0.187005
# 44809                      (GBP_curve_Down, EUR_1Y_Down)            0.180824
# 44707                       (CAD_slope_Up, EUR_slope_Up)            0.183518
# 44678                          (GBP_1Y_Up, GBP_curve_Up)            0.187005
# 44706                       (GBP_slope_Up, CAD_slope_Up)            0.184152
# 45883            (NZD_1Y_Up, EUR_slope_Up, NZD_slope_Up)            0.183518
# 45877            (GBP_slope_Up, NZD_1Y_Up, NZD_slope_Up)            0.184152
# 45594               (.DXY_Up, AUDUSD_Down, MSCI EM_Down)            0.195563
# 44677                          (GBP_curve_Up, EUR_1Y_Up)            0.189857
# 44705                          (GBP_1Y_Up, CAD_slope_Up)            0.187005
# 45848  (AUD1MO=_Up, EURO STOXX 50 VOL_Up, S&P 500 (US...            0.192552
# 45874               (NZD_1Y_Up, GBP_1Y_Up, NZD_slope_Up)            0.187005
# 45772  (EUR1MO=_Up, EURO STOXX 50 VOL_Up, S&P 500 (US...            0.192552
# 44704                          (CAD_slope_Up, EUR_1Y_Up)            0.189857
# 45738  (EURO STOXX 50 VOL_Up, AUDUSD_Down, S&P 500 (U...            0.192552
# 45872               (NZD_1Y_Up, NZD_slope_Up, EUR_1Y_Up)            0.189857
# 45813  (EURO STOXX 50 VOL_Up, JPY1MO=_Up, S&P 500 (US...            0.192552
# 45592               (.DXY_Up, NZDUSD_Down, MSCI EM_Down)            0.205071
# 45849     (AUD1MO=_Up, VIX_Up, EURO STOXX 50 (EUR)_Down)            0.199842
# 45779     (EUR1MO=_Up, VIX_Up, EURO STOXX 50 (EUR)_Down)            0.199842
# 45637           (USDNOK_Up, .DXY_Up, S&P 500 (USD)_Down)            0.198257
# 45850  (AUD1MO=_Up, S&P 500 (USD)_Down, EURO STOXX 50...            0.201426
# 45780  (EUR1MO=_Up, S&P 500 (USD)_Down, EURO STOXX 50...            0.201426
# 45741    (AUDUSD_Down, VIX_Up, EURO STOXX 50 (EUR)_Down)            0.199842
# 45635                       (USDNOK_Up, VIX_Up, .DXY_Up)            0.200000
# 45814     (JPY1MO=_Up, VIX_Up, EURO STOXX 50 (EUR)_Down)            0.199842
# 45745  (AUDUSD_Down, S&P 500 (USD)_Down, EURO STOXX 5...            0.201426
# 45815  (JPY1MO=_Up, S&P 500 (USD)_Down, EURO STOXX 50...            0.201426
#
#        consequent support   support  confidence      lift  leverage  \
# 44674            0.297623  0.103011    0.968703  3.254802  0.071362
# 37554            0.297623  0.109984    0.966574  3.247647  0.076118
# 44800            0.287956  0.100000    0.964832  3.350627  0.070155
# 44758            0.287956  0.102694    0.961424  3.338793  0.071936
# 38183            0.302536  0.108875    0.960839  3.175953  0.074594
# 44653            0.302536  0.103487    0.960294  3.174152  0.070884
# 37830            0.287956  0.110301    0.960000  3.333847  0.077216
# 37913            0.287956  0.106181    0.959885  3.333449  0.074328
# 44822            0.292868  0.101743    0.959641  3.276697  0.070693
# 38386            0.292868  0.100317    0.959091  3.274818  0.069684
# 44652            0.297623  0.103487    0.958884  3.221809  0.071366
# 44779            0.287956  0.102377    0.958457  3.328488  0.071619
# 38379            0.292868  0.111252    0.957708  3.270096  0.077231
# 44718            0.303645  0.116006    0.955614  3.147141  0.079145
# 44781            0.289540  0.102377    0.954210  3.295601  0.071312
# 37847            0.289540  0.107924    0.953782  3.294122  0.075161
# 45856            0.303645  0.100951    0.953593  3.140486  0.068806
# 37892            0.287956  0.110301    0.953425  3.311012  0.076988
# 45904            0.269731  0.100158    0.953243  3.534055  0.071818
# 45959            0.270681  0.105864    0.952924  3.520464  0.075793
# 45955            0.276704  0.105864    0.952924  3.443845  0.075124
# 37536            0.297623  0.112044    0.952830  3.201469  0.077047
# 37805            0.287956  0.105230    0.952654  3.308337  0.073422
# 37770            0.303645  0.124723    0.951632  3.134029  0.084926
# 37470            0.300317  0.107765    0.951049  3.166817  0.073736
# 38066            0.302536  0.101426    0.950966  3.143318  0.069159
# 44651            0.300317  0.103487    0.950509  3.165021  0.070790
# 45128            0.276704  0.115055    0.950262  3.434222  0.081553
# 44760            0.292868  0.102694    0.950147  3.244278  0.071040
# 45079            0.276704  0.112995    0.949401  3.431111  0.080063
# ...                   ...       ...         ...       ...       ...
# 44683            0.148019  0.103011    0.561313  3.792165  0.075847
# 44680            0.158637  0.103011    0.559380  3.526164  0.073798
# 44660            0.169731  0.103487    0.553390  3.260401  0.071746
# 44809            0.166403  0.100000    0.553024  3.323409  0.069910
# 44707            0.177338  0.101426    0.552677  3.116526  0.068882
# 44678            0.182567  0.103011    0.550847  3.017229  0.068870
# 44706            0.171949  0.101426    0.550775  3.203122  0.069761
# 45883            0.153090  0.100951    0.550086  3.593214  0.072856
# 45877            0.151664  0.100951    0.548193  3.614521  0.073022
# 45594            0.180824  0.106815    0.546191  3.020567  0.071452
# 44677            0.168938  0.103011    0.542571  3.211654  0.070937
# 44705            0.158003  0.101426    0.542373  3.432671  0.071879
# 45848            0.169572  0.103962    0.539918  3.184001  0.071311
# 45874            0.149762  0.100951    0.539831  3.604583  0.072945
# 45772            0.170840  0.103645    0.538272  3.150736  0.070750
# 44704            0.164659  0.101426    0.534224  3.244419  0.070165
# 45738            0.168146  0.102536    0.532510  3.166956  0.070159
# 45872            0.152773  0.100951    0.531720  3.480446  0.071946
# 45813            0.170840  0.102219    0.530864  3.107378  0.069323
# 45592            0.171157  0.106815    0.520866  3.043205  0.071715
# 45849            0.163708  0.103962    0.520222  3.177736  0.071246
# 45779            0.161490  0.103645    0.518636  3.211573  0.071373
# 45637            0.164818  0.102377    0.516387  3.133078  0.069701
# 45850            0.159746  0.103962    0.516129  3.230927  0.071785
# 45780            0.158796  0.103645    0.514555  3.240364  0.071659
# 45741            0.157528  0.102536    0.513085  3.257108  0.071055
# 45635            0.164818  0.102377    0.511886  3.105769  0.069414
# 45814            0.166561  0.102219    0.511499  3.070940  0.068933
# 45745            0.163233  0.102536    0.509048  3.118537  0.069656
# 45815            0.165293  0.102219    0.507474  3.070147  0.068924
#
#        conviction  antecedent_len
# 44674   22.442623               4
# 37554   21.012784               3
# 44800   20.246827               4
# 44758   18.458381               4
# 38183   17.810250               3
# 44653   17.565769               4
# 37830   17.801109               3
# 37913   17.750249               3
# 44822   17.521148               4
# 38386   17.285438               3
# 44652   17.082816               4
# 44779   17.139925               4
# 38379   16.720239               3
# 44718   15.688468               4
# 44781   15.515521               4
# 37847   15.371762               3
# 45856   15.005327               5
# 37892   15.288012               3
# 45904   15.618343               5
# 45959   15.492494               5
# 45955   15.364568               5
# 37536   14.890396               3
# 37805   15.039240               3
# 37770   14.397139               3
# 37470   14.293525               3
# 38066   14.224046               3
# 44651   14.137713               4
# 45128   14.542064               4
# 44760   14.184227               4
# 45079   14.294620               4
# ...           ...             ...
# 44683    1.942114               3
# 44680    1.909499               3
# 44660    1.859047               3
# 44809    1.864970               3
# 44707    1.839079               3
# 44678    1.819944               3
# 44706    1.843285               3
# 45883    1.882383               3
# 45877    1.877650               3
# 45594    1.805113               3
# 44677    1.816810               3
# 44705    1.839919               3
# 45848    1.804955               3
# 45874    1.847662               3
# 45772    1.795774               3
# 44704    1.793438               3
# 45738    1.779406               3
# 45872    1.809229               3
# 45813    1.767420               3
# 45592    1.729876               3
# 45849    1.743081               3
# 45779    1.741946               3
# 45637    1.726964               3
# 45850    1.736524               3
# 45780    1.732854               3
# 45741    1.730224               3
# 45635    1.711039               3
# 45814    1.706115               3
# 45745    1.704376               3
# 45815    1.694748               3
#
# [912 rows x 10 columns]

# %%
#Interesting rule example: risk off
#FXSwap implied yield curves: steeper GBP & EUR ;larger GBP FXS yield curvature & higher 1Y EUR --> higher GBP 1Y yield
print('antecedents: ' + str(rules.loc[44674].antecedents))
print('consequents: ' + str(rules.loc[44674].consequents))
print('lift: ' + "{0:.2f}".format(round(rules.loc[44674].lift,2)) + ' confidence: ' + "{0:.2f}".format(round(rules.loc[44674].confidence,2)))
# Out:
# antecedents: frozenset({'GBP_slope_Up', 'EUR_slope_Up', 'GBP_curve_Up', 'EUR_1Y_Up'})
# consequents: frozenset({'GBP_1Y_Up'})
# lift: 3.25 confidence: 0.97

# %%
#Interesting rule example: risk off
print('antecedents: ' + str(rules.loc[45849].antecedents))
print('consequents: ' + str(rules.loc[45849].consequents))
print('lift: ' + "{0:.2f}".format(round(rules.loc[45849].lift,2)) + ' confidence: ' + "{0:.2f}".format(round(rules.loc[45849].confidence,2)))
# Out:
# antecedents: frozenset({'EURO STOXX 50 VOL_Up', 'MSCI EM_Down', 'S&P 500 (USD)_Down'})
# consequents: frozenset({'AUD1MO=_Up', 'VIX_Up', 'EURO STOXX 50 (EUR)_Down'})
# lift: 3.18 confidence: 0.52
